# %%
import os

path = os.getcwd()
# find the string 'project' in the path, return index
index_project = path.find('project')
# slice the path from the index of 'project' to the end
project_path = path[:index_project+7]
# set the working directory
os.chdir(project_path)
print(f'Project path set to: {os.getcwd()}')
# Out:
# Project path set to: c:\Github\ode-biomarker-project

# %%
from PathLoader import PathLoader
path_loader = PathLoader('data_config.env', 'current_user.env')

# %%
from DataLink import DataLink
data_link = DataLink(path_loader, 'data_codes.csv')

# %% [markdown]
# ### CCLE mRNA Full Table

# %%
data_link.load_data_code('ccle')
ccle_df = data_link.data_code_database['ccle']

# %%
ccle_df.head()
# Out:
#      CELLLINE    TSPAN6      TNMD      DPM1     SCYL3  C1orf112       FGR  \
# 0  ACH-001113  4.331992  0.000000  7.364397  2.792855  4.470537  0.028569
# 1  ACH-001289  4.566815  0.584963  7.106537  2.543496  3.504620  0.000000
# 2  ACH-001339  3.150560  0.000000  7.379032  2.333424  4.227279  0.056584
# 3  ACH-001538  5.085340  0.000000  7.154109  2.545968  3.084064  0.000000
# 4  ACH-000242  6.729145  0.000000  6.537607  2.456806  3.867896  0.799087
#
#         CFH     FUCA2      GCLC  ...      H3C2      H3C3  AC098582.1  \
# 0  1.226509  3.042644  6.499686  ...  2.689299  0.189034    0.201634
# 1  0.189034  3.813525  4.221104  ...  1.286881  1.049631    0.321928
# 2  1.310340  6.687061  3.682573  ...  0.594549  1.097611    0.831877
# 3  5.868143  6.165309  4.489928  ...  0.214125  0.632268    0.298658
# 4  7.208381  5.569856  7.127014  ...  1.117695  2.358959    0.084064
#
#    DUS4L-BCAP29  C8orf44-SGK3  ELOA3B    NPBWR1  ELOA3D  ELOA3      CDR1
# 0      2.130931      0.555816     0.0  0.275007     0.0    0.0  0.000000
# 1      1.464668      0.632268     0.0  0.014355     0.0    0.0  0.000000
# 2      2.946731      0.475085     0.0  0.084064     0.0    0.0  0.042644
# 3      1.641546      0.443607     0.0  0.028569     0.0    0.0  0.000000
# 4      1.910733      0.000000     0.0  0.464668     0.0    0.0  0.000000
#
# [5 rows x 19222 columns]

# %% [markdown]
# ### Goncalves Proteomics Full Table

# %%
data_link.load_data_code('single_peptide_exclusion_matrix')
goncalves_df = data_link.data_code_database['single_peptide_exclusion_matrix']

# %%
goncalves_df.head()
# Out:
#            P37108;SRP14_HUMAN  Q96JP5;ZFP91_HUMAN  Q9Y4H2;IRS2_HUMAN  \
# model_id
# SIDM00018             7.10955             3.41494            0.00000
# SIDM00023             6.82802             4.14346            2.23781
# SIDM00040             7.01426             4.19987            2.44055
# SIDM00041             5.28591             3.35789            0.00000
# SIDM00042             5.70786             0.00000            0.00000
#
#            P36578;RL4_HUMAN  Q6SPF0;SAMD1_HUMAN  O76031;CLPX_HUMAN  \
# model_id
# SIDM00018           7.86661             3.89547            4.19666
# SIDM00023           7.62878             3.19811            4.60902
# SIDM00040           8.12459             0.00000            4.76881
# SIDM00041           7.97268             0.00000            4.52092
# SIDM00042           6.22574             0.00000            4.49579
#
#            Q8WUQ7;CATIN_HUMAN  A6NIH7;U119B_HUMAN  Q9BTD8;RBM42_HUMAN  \
# model_id
# SIDM00018                 0.0             0.00000             3.19088
# SIDM00023                 0.0             2.47059             3.69535
# SIDM00040                 0.0             0.00000             0.00000
# SIDM00041                 0.0             0.00000             2.73088
# SIDM00042                 0.0             0.00000             2.87981
#
#            Q9P258;RCC2_HUMAN  ...  P33151;CADH5_HUMAN  Q5EBL4;RIPL1_HUMAN  \
# model_id                      ...
# SIDM00018            7.35806  ...                 0.0                 0.0
# SIDM00023            5.70790  ...                 0.0                 0.0
# SIDM00040            5.52283  ...                 0.0                 0.0
# SIDM00041            4.29429  ...                 0.0                 0.0
# SIDM00042            0.00000  ...                 0.0                 0.0
#
#            P49715;CEBPA_HUMAN  Q5TA45;INT11_HUMAN  O14924;RGS12_HUMAN  \
# model_id
# SIDM00018             3.90064             2.63998                 0.0
# SIDM00023             0.00000             3.19608                 0.0
# SIDM00040             0.00000             0.00000                 0.0
# SIDM00041             0.00000             2.79023                 0.0
# SIDM00042             0.00000             0.00000                 0.0
#
#            Q7Z3B1;NEGR1_HUMAN  O60669;MOT2_HUMAN  Q13571;LAPM5_HUMAN  \
# model_id
# SIDM00018                 0.0                0.0                 0.0
# SIDM00023                 0.0                0.0                 0.0
# SIDM00040                 0.0                0.0                 0.0
# SIDM00041                 0.0                0.0                 0.0
# SIDM00042                 0.0                0.0                 0.0
#
#            Q96JM2;ZN462_HUMAN  P35558;PCKGC_HUMAN
# model_id
# SIDM00018                 0.0                 0.0
# SIDM00023                 0.0                 0.0
# SIDM00040                 0.0                 0.0
# SIDM00041                 0.0                 0.0
# SIDM00042                 0.0                 0.0
#
# [5 rows x 6692 columns]
